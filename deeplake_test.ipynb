# %% [markdown]
# <a href="https://colab.research.google.com/github/NickMattiss/ai-ml-principles-exercises/blob/main/deeplake_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deeplake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 390 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 132 kB 21.6 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 6.7 MB 41.7 MB/s
# ...
#      |████████████████████████████████| 79 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 10.2 MB 21.3 MB/s
# ...
#      |████████████████████████████████| 140 kB 36.1 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 132 kB 53.5 MB/s
# ...
#      |████████████████████████████████| 127 kB 23.8 MB/s
# ...
#   Created wheel for deeplake: filename=deeplake-3.1.2-py3-none-any.whl size=469125 sha256=d1b7d8110c7258efe5c4df3e3bc16eee439f4de7f2f23f3cce9892b39787e4d7
#   Stored in directory: /root/.cache/pip/wheels/5a/68/44/50cf3e52daf85619d0b3af63d6ae8edfab889f29b1a3a4c265
# Successfully built deeplake
# ...

# %%
import deeplake

# %%
ds1 = deeplake.load('hub://activeloop/gtsrb-test')
# Out:
# hub://activeloop/gtsrb-test loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/gtsrb-test

# %%
ds2 = deeplake.load('hub://activeloop/gtsrb-train')
# Out:
# hub://activeloop/gtsrb-train loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/gtsrb-train

# %%
len(ds1)
# len(ds2)
# Out:
# 7357

# %%
ds1.images[0]
# Out:
# Tensor(key='images', index=Index([0]))

# %%
ds2.images[0]
# Out:
# Tensor(key='images', index=Index([0]))

# %%
ds2.labels[0].numpy()
# Out:
# array([18], dtype=uint32)

# %%
labels_ds1 = ds1.labels.numpy()
labels_ds2 = ds2.labels.numpy()

# %%
labels_ds1.shape
labels_ds2.shape
# Out:
# (39209, 1)

# %%
labels_ds1[0]
# Out:
# array([11], dtype=uint32)

# %%
from PIL import Image

# %%
Image.fromarray(ds1.images(0).numpy(), "L")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-9d70c36b3951> in <module>
# ----> 1 Image.fromarray(ds1.images(0).numpy(), "L")
#
# TypeError: 'Tensor' object is not callable

# %%
import numpy as np
for im in ds1.images:
  print(np.mean(im.numpy()))
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
# 18.971177944862156
# 180.97543859649122
# 79.45344129554655
# 81.71179883945841
# 18.80836940836941
# 104.33710691823899
# 66.17648568861507
# 77.17593984962406
# 17.505936379928315
# 82.98143539913892
# 19.635256878500122
# 30.25168010752688
# 54.210188679245285
# 75.06016260162602
# 39.57007575757576
# 91.57820630547903
# 22.691258826393963
# 13.433703361085415
# 23.723775530438232
# 75.2936274509804
# 32.045815295815295
# 119.97647647647648
# 21.730867346938776
# 175.85510401548137
# 26.202116402116403
# 124.19104308390023
# 17.308045977011496
# 24.908602150537636
# 184.0200415957648
# 108.18354700854701
# 198.8751221245226
# 133.9966931216931
# 45.250956632653065
# 30.513978494623657
# 121.8867341952108
# 125.01901312811226
# 49.01446183025131
# 99.05530984698287
# 80.12886597938144
# 74.89338624338625
# 21.7643537414966
# 137.4275161588181
# 124.21769547325103
# 119.4715705128205
# 148.5270301357258
# ...
